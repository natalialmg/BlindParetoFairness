# %%
import numpy as np
import pandas as pd
import sys, os
sys.path.append("../")
from dataloaders.data_preprocessing import *
from general.utils import mkdir

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

## Adapted from : https://aif360.readthedocs.io/en/latest/modules/generated/aif360.sklearn.datasets.fetch_compas.html
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import aif360
from aif360.sklearn.datasets.compas_dataset import fetch_compas

dataset = fetch_compas(data_home=None, binary_race=False,
                       usecols=['sex', 'age', 'age_cat', 'race', 'juv_fel_count',
                          'juv_misd_count', 'juv_other_count', 'priors_count',
                          'c_charge_degree', 'c_charge_desc'],
                       dropcols=[], numeric_only=False, dropna=True)
df = dataset.X

# ## incorporate binary race white nonwhite
aux = np.array(df['race'].values)
aux[aux != 'Caucasian'] = 'nonCaucasian'
df['race_bin'] = aux

two_year_recid = []
for val in dataset.y.values:
    if val == 'Survived':
        two_year_recid.append(0)
    else:
        two_year_recid.append(1)
df['two_year_recid'] = two_year_recid
df['sample'] = np.arange(len(df))

df = df.reset_index(drop=True) #drop indexes that are provided by fetch_compas
df.head()
# Out:
#     sex  age          age_cat              race  juv_fel_count  \
# 0  Male   69  Greater than 45             Other              0
# 1  Male   34          25 - 45  African-American              0
# 2  Male   24     Less than 25  African-American              0
# 3  Male   44          25 - 45             Other              0
# 4  Male   41          25 - 45         Caucasian              0
#
#    juv_misd_count  juv_other_count  priors_count c_charge_degree  \
# 0               0                0             0               F
# 1               0                0             0               F
# 2               0                1             4               F
# 3               0                0             0               M
# 4               0                0            14               F
#
#                     c_charge_desc      race_bin  two_year_recid  sample
# 0    Aggravated Assault w/Firearm  nonCaucasian               0       0
# 1  Felony Battery w/Prior Convict  nonCaucasian               1       1
# 2           Possession of Cocaine  nonCaucasian               1       2
# 3                         Battery  nonCaucasian               0       3
# 4       Possession Burglary Tools     Caucasian               1       4

# %%
#convert categorical columns to one-hot !!exclude FAMILY INCOME!!
s_columns = ['race','race_bin','sex','two_year_recid','sample']  # extract sensitive columns
df_cat, s_dic = extract_sensitive_columns(s_columns, df)
df_cat = pd.get_dummies(df_cat)


print('Categories')
samples = df['sample'].values
for cat in sorted(df_cat.columns):
    print(cat,df_cat[cat].dtype)
    if (df_cat[cat].dtype == 'uint8') | (df_cat[cat].dtype == 'int64'):
        print(np.sum(df_cat[cat].values > 0))
        if np.sum(df_cat[cat].values > 0) < 20:
            samples = samples[df_cat[cat].values != 1] #remove samples with this feature on
            df_cat = df_cat[df_cat[cat] != 1] #remove samples with this feature on
            df_cat = df_cat.drop(columns = [cat])
            print('Too small dropped')
print()

#incorporate sensitive_columns
print('Sensitive columns')
for s in s_columns:
    print(s)
    df_cat[s] = s_dic[s].values[samples]
print()

df_cat.groupby(['sex','race_bin','two_year_recid']).count()
# Out:
# Categories
# age int64
# 6167
# age_cat_25 - 45 uint8
# 3528
# age_cat_Greater than 45 uint8
# 1292
# age_cat_Less than 25 uint8
# 1347
# c_charge_degree_F uint8
# 3966
# c_charge_degree_M uint8
# 2201
# c_charge_desc_Abuse Without Great Harm uint8
# 1
# Too small dropped
# c_charge_desc_Agg Abuse Elderlly/Disabled Adult uint8
# 1
# Too small dropped
# c_charge_desc_Agg Assault W/int Com Fel Dome uint8
# 7
# Too small dropped
# c_charge_desc_Agg Battery Grt/Bod/Harm uint8
# 31
# c_charge_desc_Agg Fleeing and Eluding uint8
# 6
# Too small dropped
# c_charge_desc_Agg Fleeing/Eluding High Speed uint8
# 2
# Too small dropped
# c_charge_desc_Aggr Child Abuse-Torture,Punish uint8
# 1
# Too small dropped
# c_charge_desc_Aggrav Battery w/Deadly Weapon uint8
# 57
# c_charge_desc_Aggrav Child Abuse-Agg Battery uint8
# 3
# Too small dropped
# c_charge_desc_Aggrav Child Abuse-Causes Harm uint8
# 1
# Too small dropped
# c_charge_desc_Aggrav Stalking After Injunctn uint8
# 6
# Too small dropped
# c_charge_desc_Aggravated Assault uint8
# 5
# Too small dropped
# c_charge_desc_Aggravated Assault W/Dead Weap uint8
# 54
# c_charge_desc_Aggravated Assault W/dead Weap uint8
# 34
# c_charge_desc_Aggravated Assault W/o Firearm uint8
# 2
# Too small dropped
# c_charge_desc_Aggravated Assault w/Firearm uint8
# 22
# c_charge_desc_Aggravated Battery uint8
# 20
# c_charge_desc_Aggravated Battery (Firearm) uint8
# 1
# Too small dropped
# c_charge_desc_Aggravated Battery (Firearm/Actual Possession) uint8
# 1
# Too small dropped
# c_charge_desc_Aggravated Battery / Pregnant uint8
# 48
# c_charge_desc_Aggravated Battery On 65/Older uint8
# 2
# Too small dropped
# c_charge_desc_Aide/Abet Prostitution Lewdness uint8
# 1
# Too small dropped
# c_charge_desc_Aiding Escape uint8
# 2
# Too small dropped
# c_charge_desc_Alcoholic Beverage Violation-FL uint8
# 2
# Too small dropped
# c_charge_desc_Armed Trafficking in Cannabis uint8
# 1
# Too small dropped
# c_charge_desc_Arson in the First Degree uint8
# 1
# Too small dropped
# c_charge_desc_Assault uint8
# 38
# c_charge_desc_Assault Law Enforcement Officer uint8
# 1
# Too small dropped
# c_charge_desc_Att Burgl Conv Occp uint8
# 1
# Too small dropped
# c_charge_desc_Att Burgl Struc/Conv Dwel/Occp uint8
# 1
# Too small dropped
# c_charge_desc_Att Burgl Unoccupied Dwel uint8
# 10
# Too small dropped
# c_charge_desc_Att Tamper w/Physical Evidence uint8
# 4
# Too small dropped
# c_charge_desc_Attempt Armed Burglary Dwell uint8
# 1
# Too small dropped
# c_charge_desc_Attempted Burg/Convey/Unocc uint8
# 3
# Too small dropped
# c_charge_desc_Attempted Burg/struct/unocc uint8
# 1
# Too small dropped
# c_charge_desc_Attempted Deliv Control Subst uint8
# 1
# Too small dropped
# c_charge_desc_Attempted Robbery  No Weapon uint8
# 3
# Too small dropped
# c_charge_desc_Attempted Robbery  Weapon uint8
# 1
# Too small dropped
# c_charge_desc_Battery uint8
# 1087
# c_charge_desc_Battery Emergency Care Provide uint8
# 1
# Too small dropped
# c_charge_desc_Battery On A Person Over 65 uint8
# 1
# Too small dropped
# c_charge_desc_Battery On Fire Fighter uint8
# 1
# Too small dropped
# c_charge_desc_Battery On Parking Enfor Speci uint8
# 1
# Too small dropped
# c_charge_desc_Battery Spouse Or Girlfriend uint8
# 1
# Too small dropped
# c_charge_desc_Battery on Law Enforc Officer uint8
# 46
# c_charge_desc_Battery on a Person Over 65 uint8
# 16
# Too small dropped
# c_charge_desc_Bribery Athletic Contests uint8
# 1
# Too small dropped
# c_charge_desc_Burgl Dwel/Struct/Convey Armed uint8
# 1
# Too small dropped
# c_charge_desc_Burglary Assault/Battery Armed uint8
# 2
# Too small dropped
# c_charge_desc_Burglary Conveyance Armed uint8
# 5
# Too small dropped
# c_charge_desc_Burglary Conveyance Assault/Bat uint8
# 5
# Too small dropped
# c_charge_desc_Burglary Conveyance Occupied uint8
# 4
# Too small dropped
# c_charge_desc_Burglary Conveyance Unoccup uint8
# 68
# c_charge_desc_Burglary Dwelling Armed uint8
# 6
# Too small dropped
# c_charge_desc_Burglary Dwelling Assault/Batt uint8
# 17
# Too small dropped
# c_charge_desc_Burglary Dwelling Occupied uint8
# 26
# c_charge_desc_Burglary Structure Assault/Batt uint8
# 1
# Too small dropped
# c_charge_desc_Burglary Structure Occupied uint8
# 1
# Too small dropped
# c_charge_desc_Burglary Structure Unoccup uint8
# 35
# c_charge_desc_Burglary Unoccupied Dwelling uint8
# 77
# c_charge_desc_Burglary With Assault/battery uint8
# 8
# Too small dropped
# c_charge_desc_Carjacking w/o Deadly Weapon uint8
# 1
# Too small dropped
# c_charge_desc_Carjacking with a Firearm uint8
# 1
# Too small dropped
# c_charge_desc_Carry Open/Uncov Bev In Pub uint8
# 2
# Too small dropped
# c_charge_desc_Carrying A Concealed Weapon uint8
# 1
# Too small dropped
# c_charge_desc_Carrying Concealed Firearm uint8
# 34
# c_charge_desc_Cash Item w/Intent to Defraud uint8
# 2
# Too small dropped
# c_charge_desc_Child Abuse uint8
# 15
# Too small dropped
# c_charge_desc_Computer Pornography uint8
# 1
# Too small dropped
# c_charge_desc_Consp Traff Oxycodone  4g><14g uint8
# 1
# Too small dropped
# c_charge_desc_Conspiracy Dealing Stolen Prop uint8
# 1
# Too small dropped
# c_charge_desc_Consume Alcoholic Bev Pub uint8
# 1
# Too small dropped
# c_charge_desc_Contradict Statement uint8
# 1
# Too small dropped
# c_charge_desc_Contribute Delinquency Of A Minor uint8
# 1
# Too small dropped
# c_charge_desc_Corrupt Public Servant uint8
# 11
# Too small dropped
# c_charge_desc_Counterfeit Lic Plates/Sticker uint8
# 1
# Too small dropped
# c_charge_desc_Crim Attempt/Solic/Consp uint8
# 1
# Too small dropped
# c_charge_desc_Crim Use of Personal ID Info uint8
# 26
# c_charge_desc_Crimin Mischief Damage $1000+ uint8
# 17
# Too small dropped
# c_charge_desc_Criminal Mischief uint8
# 15
# Too small dropped
# c_charge_desc_Criminal Mischief Damage <$200 uint8
# 13
# Too small dropped
# c_charge_desc_Criminal Mischief>$200<$1000 uint8
# 7
# Too small dropped
# c_charge_desc_Crlty Twrd Child Urge Oth Act uint8
# 1
# Too small dropped
# c_charge_desc_Cruelty Toward Child uint8
# 11
# Too small dropped
# c_charge_desc_Cruelty to Animals uint8
# 1
# Too small dropped
# c_charge_desc_Culpable Negligence uint8
# 2
# Too small dropped
# c_charge_desc_D.U.I. Serious Bodily Injury uint8
# 2
# Too small dropped
# c_charge_desc_DOC/Cause Public Danger uint8
# 2
# Too small dropped
# c_charge_desc_DUI - Enhanced uint8
# 14
# Too small dropped
# c_charge_desc_DUI - Property Damage/Personal Injury uint8
# 1
# Too small dropped
# c_charge_desc_DUI Blood Alcohol Above 0.20 uint8
# 4
# Too small dropped
# c_charge_desc_DUI Level 0.15 Or Minor In Veh uint8
# 54
# c_charge_desc_DUI Property Damage/Injury uint8
# 70
# c_charge_desc_DUI- Enhanced uint8
# 5
# Too small dropped
# c_charge_desc_DUI/Property Damage/Persnl Inj uint8
# 2
# Too small dropped
# c_charge_desc_DWI w/Inj Susp Lic / Habit Off uint8
# 2
# Too small dropped
# c_charge_desc_DWLS Canceled Disqul 1st Off uint8
# 2
# Too small dropped
# c_charge_desc_DWLS Susp/Cancel Revoked uint8
# 1
# Too small dropped
# c_charge_desc_Dealing in Stolen Property uint8
# 11
# Too small dropped
# c_charge_desc_Defrauding Innkeeper uint8
# 1
# Too small dropped
# c_charge_desc_Defrauding Innkeeper $300/More uint8
# 1
# Too small dropped
# c_charge_desc_Del 3,4 Methylenedioxymethcath uint8
# 1
# Too small dropped
# c_charge_desc_Del Cannabis At/Near Park uint8
# 2
# Too small dropped
# c_charge_desc_Del Cannabis For Consideration uint8
# 4
# Too small dropped
# c_charge_desc_Del of JWH-250 2-Methox 1-Pentyl uint8
# 1
# Too small dropped
# c_charge_desc_Deliver 3,4 Methylenediox uint8
# 14
# Too small dropped
# c_charge_desc_Deliver Alprazolam uint8
# 1
# Too small dropped
# c_charge_desc_Deliver Cannabis uint8
# 17
# Too small dropped
# c_charge_desc_Deliver Cannabis 1000FTSch uint8
# 1
# Too small dropped
# c_charge_desc_Deliver Cocaine uint8
# 23
# c_charge_desc_Deliver Cocaine 1000FT Church uint8
# 1
# Too small dropped
# c_charge_desc_Deliver Cocaine 1000FT Park uint8
# 1
# Too small dropped
# c_charge_desc_Deliver Cocaine 1000FT School uint8
# 1
# Too small dropped
# c_charge_desc_Deliver Cocaine 1000FT Store uint8
# 1
# Too small dropped
# c_charge_desc_Delivery Of Drug Paraphernalia uint8
# 1
# Too small dropped
# c_charge_desc_Delivery of 5-Fluoro PB-22 uint8
# 1
# Too small dropped
# c_charge_desc_Delivery of Heroin uint8
# 1
# Too small dropped
# c_charge_desc_Depriv LEO of Protect/Communic uint8
# 2
# Too small dropped
# c_charge_desc_Disorderly Conduct uint8
# 27
# c_charge_desc_Disorderly Intoxication uint8
# 13
# Too small dropped
# c_charge_desc_Disrupting School Function uint8
# 1
# Too small dropped
# c_charge_desc_Drivg While Lic Suspd/Revk/Can uint8
# 7
# Too small dropped
# c_charge_desc_Driving License Suspended uint8
# 44
# c_charge_desc_Driving Under The Influence uint8
# 126
# c_charge_desc_Driving While License Revoked uint8
# 189
# c_charge_desc_Escape uint8
# 2
# Too small dropped
# c_charge_desc_Exhibition Weapon School Prop uint8
# 1
# Too small dropped
# c_charge_desc_Expired DL More Than 6 Months uint8
# 5
# Too small dropped
# c_charge_desc_Exposes Culpable Negligence uint8
# 12
# Too small dropped
# c_charge_desc_Extradition/Defendants uint8
# 2
# Too small dropped
# c_charge_desc_Fabricating Physical Evidence uint8
# 1
# Too small dropped
# c_charge_desc_Fail Register Vehicle uint8
# 6
# Too small dropped
# c_charge_desc_Fail Sex Offend Report Bylaw uint8
# 1
# Too small dropped
# c_charge_desc_Fail To Obey Police Officer uint8
# 4
# Too small dropped
# c_charge_desc_Fail To Redeliv Hire/Leas Prop uint8
# 3
# Too small dropped
# c_charge_desc_Failure To Pay Taxi Cab Charge uint8
# 1
# Too small dropped
# c_charge_desc_Failure To Return Hired Vehicle uint8
# 5
# Too small dropped
# c_charge_desc_False 911 Call uint8
# 1
# Too small dropped
# c_charge_desc_False Bomb Report uint8
# 1
# Too small dropped
# c_charge_desc_False Imprisonment uint8
# 24
# c_charge_desc_False Info LEO During Invest uint8
# 1
# Too small dropped
# c_charge_desc_False Motor Veh Insurance Card uint8
# 3
# Too small dropped
# c_charge_desc_False Name By Person Arrest uint8
# 1
# Too small dropped
# c_charge_desc_False Ownership Info/Pawn Item uint8
# 16
# Too small dropped
# c_charge_desc_Falsely Impersonating Officer uint8
# 1
# Too small dropped
# c_charge_desc_Fel Drive License Perm Revoke uint8
# 3
# Too small dropped
# c_charge_desc_Felon in Pos of Firearm or Amm uint8
# 1
# Too small dropped
# c_charge_desc_Felony Batt(Great Bodily Harm) uint8
# 9
# Too small dropped
# c_charge_desc_Felony Battery uint8
# 12
# Too small dropped
# c_charge_desc_Felony Battery (Dom Strang) uint8
# 92
# c_charge_desc_Felony Battery w/Prior Convict uint8
# 38
# c_charge_desc_Felony Committing Prostitution uint8
# 3
# Too small dropped
# c_charge_desc_Felony DUI (level 3) uint8
# 7
# Too small dropped
# c_charge_desc_Felony DUI - Enhanced uint8
# 1
# Too small dropped
# c_charge_desc_Felony Driving While Lic Suspd uint8
# 93
# c_charge_desc_Felony Petit Theft uint8
# 60
# c_charge_desc_Felony/Driving Under Influence uint8
# 6
# Too small dropped
# c_charge_desc_Fighting/Baiting Animals uint8
# 2
# Too small dropped
# c_charge_desc_Fleeing Or Attmp Eluding A Leo uint8
# 15
# Too small dropped
# c_charge_desc_Fleeing or Eluding a LEO uint8
# 8
# Too small dropped
# c_charge_desc_Forging Bank Bills/Promis Note uint8
# 3
# Too small dropped
# c_charge_desc_Fraudulent Use of Credit Card uint8
# 6
# Too small dropped
# c_charge_desc_Grand Theft (Motor Vehicle) uint8
# 92
# c_charge_desc_Grand Theft Dwell Property uint8
# 4
# Too small dropped
# c_charge_desc_Grand Theft Firearm uint8
# 6
# Too small dropped
# c_charge_desc_Grand Theft in the 1st Degree uint8
# 3
# Too small dropped
# c_charge_desc_Grand Theft in the 3rd Degree uint8
# 384
# c_charge_desc_Grand Theft of a Fire Extinquisher uint8
# 1
# Too small dropped
# c_charge_desc_Grand Theft of the 2nd Degree uint8
# 2
# Too small dropped
# c_charge_desc_Grand Theft on 65 Yr or Older uint8
# 2
# Too small dropped
# c_charge_desc_Harass Witness/Victm/Informnt uint8
# 1
# Too small dropped
# c_charge_desc_Harm Public Servant Or Family uint8
# 2
# Too small dropped
# c_charge_desc_Hiring with Intent to Defraud uint8
# 1
# Too small dropped
# c_charge_desc_Imperson Public Officer or Emplyee uint8
# 1
# Too small dropped
# c_charge_desc_Interfere W/Traf Cont Dev RR uint8
# 1
# Too small dropped
# c_charge_desc_Interference with Custody uint8
# 1
# Too small dropped
# c_charge_desc_Intoxicated/Safety Of Another uint8
# 1
# Too small dropped
# c_charge_desc_Introduce Contraband Into Jail uint8
# 6
# Too small dropped
# c_charge_desc_Issuing a Worthless Draft uint8
# 1
# Too small dropped
# c_charge_desc_Kidnapping / Domestic Violence uint8
# 2
# Too small dropped
# c_charge_desc_Lease For Purpose Trafficking uint8
# 1
# Too small dropped
# c_charge_desc_Leave Acc/Attend Veh/More $50 uint8
# 8
# Too small dropped
# c_charge_desc_Leave Accd/Attend Veh/Less $50 uint8
# 2
# Too small dropped
# c_charge_desc_Leaving Acc/Unattended Veh uint8
# 10
# Too small dropped
# c_charge_desc_Leaving the Scene of Accident uint8
# 12
# Too small dropped
# c_charge_desc_Lewd Act Presence Child 16- uint8
# 1
# Too small dropped
# c_charge_desc_Lewd or Lascivious Molestation uint8
# 6
# Too small dropped
# c_charge_desc_Lewd/Lasc Battery Pers 12+/<16 uint8
# 5
# Too small dropped
# c_charge_desc_Lewd/Lasc Exhib Presence <16yr uint8
# 1
# Too small dropped
# c_charge_desc_Lewd/Lasciv Molest Elder Persn uint8
# 1
# Too small dropped
# c_charge_desc_Lewdness Violation uint8
# 2
# Too small dropped
# c_charge_desc_License Suspended Revoked uint8
# 1
# Too small dropped
# c_charge_desc_Littering uint8
# 1
# Too small dropped
# c_charge_desc_Live on Earnings of Prostitute uint8
# 4
# Too small dropped
# c_charge_desc_Lve/Scen/Acc/Veh/Prop/Damage uint8
# 12
# Too small dropped
# c_charge_desc_Manage Busn W/O City Occup Lic uint8
# 1
# Too small dropped
# c_charge_desc_Manslaughter W/Weapon/Firearm uint8
# 1
# Too small dropped
# c_charge_desc_Manufacture Cannabis uint8
# 7
# Too small dropped
# c_charge_desc_Misuse Of 911 Or E911 System uint8
# 1
# Too small dropped
# c_charge_desc_Money Launder 100K or More Dols uint8
# 1
# Too small dropped
# c_charge_desc_Murder In 2nd Degree W/firearm uint8
# 1
# Too small dropped
# c_charge_desc_Murder in the First Degree uint8
# 1
# Too small dropped
# c_charge_desc_Neglect Child / Bodily Harm uint8
# 4
# Too small dropped
# c_charge_desc_Neglect Child / No Bodily Harm uint8
# 20
# c_charge_desc_Neglect/Abuse Elderly Person uint8
# 1
# Too small dropped
# c_charge_desc_Obstruct Fire Equipment uint8
# 3
# Too small dropped
# c_charge_desc_Obstruct Officer W/Violence uint8
# 1
# Too small dropped
# c_charge_desc_Obtain Control Substance By Fraud uint8
# 1
# Too small dropped
# c_charge_desc_Offer Agree Secure For Lewd Act uint8
# 1
# Too small dropped
# c_charge_desc_Offer Agree Secure/Lewd Act uint8
# 1
# Too small dropped
# c_charge_desc_Offn Against Intellectual Prop uint8
# 1
# Too small dropped
# c_charge_desc_Open Carrying Of Weapon uint8
# 1
# Too small dropped
# c_charge_desc_Oper Motorcycle W/O Valid DL uint8
# 1
# Too small dropped
# c_charge_desc_Operating W/O Valid License uint8
# 28
# c_charge_desc_Opert With Susp DL 2nd Offens uint8
# 5
# Too small dropped
# c_charge_desc_PL/Unlaw Use Credit Card uint8
# 1
# Too small dropped
# c_charge_desc_Petit Theft uint8
# 29
# c_charge_desc_Petit Theft $100- $300 uint8
# 14
# Too small dropped
# c_charge_desc_Pos Cannabis For Consideration uint8
# 1
# Too small dropped
# c_charge_desc_Pos Cannabis W/Intent Sel/Del uint8
# 93
# c_charge_desc_Pos Methylenedioxymethcath W/I/D/S uint8
# 1
# Too small dropped
# c_charge_desc_Poss 3,4 MDMA (Ecstasy) uint8
# 9
# Too small dropped
# c_charge_desc_Poss Alprazolam W/int Sell/Del uint8
# 1
# Too small dropped
# c_charge_desc_Poss Anti-Shoplifting Device uint8
# 3
# Too small dropped
# c_charge_desc_Poss Cntrft Contr Sub w/Intent uint8
# 2
# Too small dropped
# c_charge_desc_Poss Cocaine/Intent To Del/Sel uint8
# 13
# Too small dropped
# c_charge_desc_Poss Contr Subst W/o Prescript uint8
# 21
# c_charge_desc_Poss Counterfeit Payment Inst uint8
# 1
# Too small dropped
# c_charge_desc_Poss Drugs W/O A Prescription uint8
# 1
# Too small dropped
# c_charge_desc_Poss F/Arm Delinq uint8
# 4
# Too small dropped
# c_charge_desc_Poss Firearm W/Altered ID# uint8
# 1
# Too small dropped
# c_charge_desc_Poss Meth/Diox/Meth/Amp (MDMA) uint8
# 2
# Too small dropped
# c_charge_desc_Poss Of 1,4-Butanediol uint8
# 1
# Too small dropped
# c_charge_desc_Poss Of Controlled Substance uint8
# 6
# Too small dropped
# c_charge_desc_Poss Of RX Without RX uint8
# 2
# Too small dropped
# c_charge_desc_Poss Oxycodone W/Int/Sell/Del uint8
# 1
# Too small dropped
# c_charge_desc_Poss Pyrrolidinobutiophenone uint8
# 1
# Too small dropped
# c_charge_desc_Poss Pyrrolidinovalerophenone uint8
# 37
# c_charge_desc_Poss Pyrrolidinovalerophenone W/I/D/S uint8
# 1
# Too small dropped
# c_charge_desc_Poss Similitude of Drivers Lic uint8
# 3
# Too small dropped
# c_charge_desc_Poss Tetrahydrocannabinols uint8
# 4
# Too small dropped
# c_charge_desc_Poss Unlaw Issue Driver Licenc uint8
# 6
# Too small dropped
# c_charge_desc_Poss Unlaw Issue Id uint8
# 2
# Too small dropped
# c_charge_desc_Poss Wep Conv Felon uint8
# 6
# Too small dropped
# c_charge_desc_Poss of Cocaine W/I/D/S 1000FT Park uint8
# 6
# Too small dropped
# c_charge_desc_Poss of Firearm by Convic Felo uint8
# 3
# Too small dropped
# c_charge_desc_Poss of Methylethcathinone uint8
# 3
# Too small dropped
# c_charge_desc_Poss/Sell/Del Cocaine 1000FT Sch uint8
# 2
# Too small dropped
# c_charge_desc_Poss/Sell/Del/Man Amobarbital uint8
# 1
# Too small dropped
# c_charge_desc_Poss/pur/sell/deliver Cocaine uint8
# 1
# Too small dropped
# c_charge_desc_Poss3,4 Methylenedioxymethcath uint8
# 68
# c_charge_desc_Posses/Disply Susp/Revk/Frd DL uint8
# 2
# Too small dropped
# c_charge_desc_Possess Cannabis 1000FTSch uint8
# 1
# Too small dropped
# c_charge_desc_Possess Cannabis/20 Grams Or Less uint8
# 79
# c_charge_desc_Possess Controlled Substance uint8
# 1
# Too small dropped
# c_charge_desc_Possess Countrfeit Credit Card uint8
# 1
# Too small dropped
# c_charge_desc_Possess Drug Paraphernalia uint8
# 6
# Too small dropped
# c_charge_desc_Possess Mot Veh W/Alt Vin # uint8
# 1
# Too small dropped
# c_charge_desc_Possess Tobacco Product Under 18 uint8
# 1
# Too small dropped
# c_charge_desc_Possess Weapon On School Prop uint8
# 1
# Too small dropped
# c_charge_desc_Possess w/I/Utter Forged Bills uint8
# 1
# Too small dropped
# c_charge_desc_Possession Burglary Tools uint8
# 29
# c_charge_desc_Possession Child Pornography uint8
# 1
# Too small dropped
# c_charge_desc_Possession Firearm School Prop uint8
# 1
# Too small dropped
# c_charge_desc_Possession Of 3,4Methylenediox uint8
# 1
# Too small dropped
# c_charge_desc_Possession Of Alprazolam uint8
# 44
# c_charge_desc_Possession Of Amphetamine uint8
# 5
# Too small dropped
# c_charge_desc_Possession Of Anabolic Steroid uint8
# 1
# Too small dropped
# c_charge_desc_Possession Of Buprenorphine uint8
# 1
# Too small dropped
# c_charge_desc_Possession Of Carisoprodol uint8
# 2
# Too small dropped
# c_charge_desc_Possession Of Clonazepam uint8
# 1
# Too small dropped
# c_charge_desc_Possession Of Cocaine uint8
# 1
# Too small dropped
# c_charge_desc_Possession Of Diazepam uint8
# 1
# Too small dropped
# c_charge_desc_Possession Of Fentanyl uint8
# 1
# Too small dropped
# c_charge_desc_Possession Of Heroin uint8
# 21
# c_charge_desc_Possession Of Methamphetamine uint8
# 26
# c_charge_desc_Possession Of Paraphernalia uint8
# 1
# Too small dropped
# c_charge_desc_Possession Of Phentermine uint8
# 1
# Too small dropped
# c_charge_desc_Possession of Alcohol Under 21 uint8
# 1
# Too small dropped
# c_charge_desc_Possession of Benzylpiperazine uint8
# 2
# Too small dropped
# c_charge_desc_Possession of Butylone uint8
# 1
# Too small dropped
# c_charge_desc_Possession of Cannabis uint8
# 68
# c_charge_desc_Possession of Cocaine uint8
# 419
# c_charge_desc_Possession of Codeine uint8
# 3
# Too small dropped
# c_charge_desc_Possession of Ethylone uint8
# 3
# Too small dropped
# c_charge_desc_Possession of Hydrocodone uint8
# 7
# Too small dropped
# c_charge_desc_Possession of Hydromorphone uint8
# 12
# Too small dropped
# c_charge_desc_Possession of LSD uint8
# 2
# Too small dropped
# c_charge_desc_Possession of Methadone uint8
# 1
# Too small dropped
# c_charge_desc_Possession of Morphine uint8
# 4
# Too small dropped
# c_charge_desc_Possession of Oxycodone uint8
# 22
# c_charge_desc_Possession of XLR11 uint8
# 1
# Too small dropped
# c_charge_desc_Principal In The First Degree uint8
# 1
# Too small dropped
# c_charge_desc_Prostitution uint8
# 1
# Too small dropped
# c_charge_desc_Prostitution/Lewd Act Assignation uint8
# 8
# Too small dropped
# c_charge_desc_Prostitution/Lewdness/Assign uint8
# 2
# Too small dropped
# c_charge_desc_Prowling/Loitering uint8
# 10
# Too small dropped
# c_charge_desc_Purchase Cannabis uint8
# 6
# Too small dropped
# c_charge_desc_Purchase/P/W/Int Cannabis uint8
# 1
# Too small dropped
# c_charge_desc_Reckless Driving uint8
# 7
# Too small dropped
# c_charge_desc_Refuse Submit Blood/Breath Test uint8
# 2
# Too small dropped
# c_charge_desc_Refuse to Supply DNA Sample uint8
# 1
# Too small dropped
# c_charge_desc_Resist Officer w/Violence uint8
# 46
# c_charge_desc_Resist/Obstruct W/O Violence uint8
# 36
# c_charge_desc_Retail Theft $300 1st Offense uint8
# 3
# Too small dropped
# c_charge_desc_Retail Theft $300 2nd Offense uint8
# 1
# Too small dropped
# c_charge_desc_Ride Tri-Rail Without Paying uint8
# 1
# Too small dropped
# c_charge_desc_Robbery / No Weapon uint8
# 19
# Too small dropped
# c_charge_desc_Robbery / Weapon uint8
# 5
# Too small dropped
# c_charge_desc_Robbery Sudd Snatch No Weapon uint8
# 11
# Too small dropped
# c_charge_desc_Robbery W/Deadly Weapon uint8
# 1
# Too small dropped
# c_charge_desc_Robbery W/Firearm uint8
# 2
# Too small dropped
# c_charge_desc_Sale/Del Cannabis At/Near Scho uint8
# 3
# Too small dropped
# c_charge_desc_Sale/Del Counterfeit Cont Subs uint8
# 1
# Too small dropped
# c_charge_desc_Sel/Pur/Mfr/Del Control Substa uint8
# 1
# Too small dropped
# c_charge_desc_Sell or Offer for Sale Counterfeit Goods uint8
# 3
# Too small dropped
# c_charge_desc_Sell/Man/Del Pos/w/int Heroin uint8
# 1
# Too small dropped
# c_charge_desc_Sex Batt Faml/Cust Vict 12-17Y uint8
# 1
# Too small dropped
# c_charge_desc_Sex Battery Deft 18+/Vict 11- uint8
# 1
# Too small dropped
# c_charge_desc_Sex Offender Fail Comply W/Law uint8
# 2
# Too small dropped
# c_charge_desc_Sexual Battery / Vict 12 Yrs + uint8
# 2
# Too small dropped
# c_charge_desc_Sexual Performance by a Child uint8
# 1
# Too small dropped
# c_charge_desc_Shoot In Occupied Dwell uint8
# 1
# Too small dropped
# c_charge_desc_Shoot Into Vehicle uint8
# 2
# Too small dropped
# c_charge_desc_Simulation of Legal Process uint8
# 1
# Too small dropped
# c_charge_desc_Solic to Commit Battery uint8
# 2
# Too small dropped
# c_charge_desc_Solicit Deliver Cocaine uint8
# 4
# Too small dropped
# c_charge_desc_Solicit Purchase Cocaine uint8
# 1
# Too small dropped
# c_charge_desc_Solicit To Deliver Cocaine uint8
# 1
# Too small dropped
# c_charge_desc_Solicitation On Felony 3 Deg uint8
# 4
# Too small dropped
# c_charge_desc_Soliciting For Prostitution uint8
# 2
# Too small dropped
# c_charge_desc_Sound Articles Over 100 uint8
# 1
# Too small dropped
# c_charge_desc_Stalking uint8
# 1
# Too small dropped
# c_charge_desc_Stalking (Aggravated) uint8
# 6
# Too small dropped
# c_charge_desc_Strong Armed  Robbery uint8
# 2
# Too small dropped
# c_charge_desc_Structuring Transactions uint8
# 1
# Too small dropped
# c_charge_desc_Susp Drivers Lic 1st Offense uint8
# 45
# c_charge_desc_Tamper With Victim uint8
# 2
# Too small dropped
# c_charge_desc_Tamper With Witness uint8
# 2
# Too small dropped
# c_charge_desc_Tamper With Witness/Victim/CI uint8
# 21
# c_charge_desc_Tampering With Physical Evidence uint8
# 46
# c_charge_desc_Tampering with a Victim uint8
# 1
# Too small dropped
# c_charge_desc_Theft/To Deprive uint8
# 1
# Too small dropped
# c_charge_desc_Threat Public Servant uint8
# 3
# Too small dropped
# c_charge_desc_Throw Deadly Missile Into Veh uint8
# 3
# Too small dropped
# c_charge_desc_Throw In Occupied Dwell uint8
# 1
# Too small dropped
# c_charge_desc_Throw Missile Into Pub/Priv Dw uint8
# 1
# Too small dropped
# c_charge_desc_Traff In Cocaine <400g>150 Kil uint8
# 1
# Too small dropped
# c_charge_desc_Traffic Counterfeit Cred Cards uint8
# 1
# Too small dropped
# c_charge_desc_Traffick Amphetamine 28g><200g uint8
# 2
# Too small dropped
# c_charge_desc_Traffick Oxycodone     4g><14g uint8
# 1
# Too small dropped
# c_charge_desc_Trans/Harm/Material to a Minor uint8
# 1
# Too small dropped
# c_charge_desc_Trespass On School Grounds uint8
# 1
# Too small dropped
# c_charge_desc_Trespass Other Struct/Conve uint8
# 1
# Too small dropped
# c_charge_desc_Trespass Private Property uint8
# 1
# Too small dropped
# c_charge_desc_Trespass Property w/Dang Weap uint8
# 1
# Too small dropped
# c_charge_desc_Trespass Struct/Conveyance uint8
# 2
# Too small dropped
# c_charge_desc_Trespass Structure w/Dang Weap uint8
# 1
# Too small dropped
# c_charge_desc_Trespass Structure/Conveyance uint8
# 1
# Too small dropped
# c_charge_desc_Trespassing/Construction Site uint8
# 4
# Too small dropped
# c_charge_desc_Tresspass Struct/Conveyance uint8
# 4
# Too small dropped
# c_charge_desc_Tresspass in Structure or Conveyance uint8
# 2
# Too small dropped
# c_charge_desc_Unauth C/P/S Sounds>1000/Audio uint8
# 1
# Too small dropped
# c_charge_desc_Unauth Poss ID Card or DL uint8
# 8
# Too small dropped
# c_charge_desc_Unauthorized Interf w/Railroad uint8
# 1
# Too small dropped
# c_charge_desc_Unl/Disturb Education/Instui uint8
# 1
# Too small dropped
# c_charge_desc_Unlaw Lic Use/Disply Of Others uint8
# 1
# Too small dropped
# c_charge_desc_Unlaw LicTag/Sticker Attach uint8
# 9
# Too small dropped
# c_charge_desc_Unlaw Use False Name/Identity uint8
# 5
# Too small dropped
# c_charge_desc_Unlawful Conveyance of Fuel uint8
# 1
# Too small dropped
# c_charge_desc_Unlicensed Telemarketing uint8
# 2
# Too small dropped
# c_charge_desc_Use Computer for Child Exploit uint8
# 1
# Too small dropped
# c_charge_desc_Use Of 2 Way Device To Fac Fel uint8
# 1
# Too small dropped
# c_charge_desc_Use Scanning Device to Defraud uint8
# 1
# Too small dropped
# c_charge_desc_Use of Anti-Shoplifting Device uint8
# 4
# Too small dropped
# c_charge_desc_Uttering Forged Bills uint8
# 5
# Too small dropped
# c_charge_desc_Uttering Forged Credit Card uint8
# 1
# Too small dropped
# c_charge_desc_Uttering Worthless Check +$150 uint8
# 1
# Too small dropped
# c_charge_desc_Uttering a Forged Instrument uint8
# 47
# c_charge_desc_Video Voyeur-<24Y on Child >16 uint8
# 1
# Too small dropped
# c_charge_desc_Viol Injunct Domestic Violence uint8
# 47
# c_charge_desc_Viol Injunction Protect Dom Vi uint8
# 6
# Too small dropped
# c_charge_desc_Viol Pretrial Release Dom Viol uint8
# 12
# Too small dropped
# c_charge_desc_Viol Prot Injunc Repeat Viol uint8
# 18
# Too small dropped
# c_charge_desc_Violation License Restrictions uint8
# 1
# Too small dropped
# c_charge_desc_Violation Of Boater Safety Id uint8
# 1
# Too small dropped
# c_charge_desc_Violation of Injunction Order/Stalking/Cyberstalking uint8
# 1
# Too small dropped
# c_charge_desc_Voyeurism uint8
# 1
# Too small dropped
# c_charge_desc_arrest case no charge uint8
# 784
# juv_fel_count int64
# 177
# juv_misd_count int64
# 302
# juv_other_count int64
# 374
# priors_count int64
# 3411
#
# Sensitive columns
# race
# race_bin
# sex
# two_year_recid
# sample
#                                      age  juv_fel_count  juv_misd_count  \
# sex    race_bin     two_year_recid
# Female Caucasian    0                262            262             262
#                     1                143            143             143
#        nonCaucasian 0                373            373             373
#                     1                197            197             197
# Male   Caucasian    0                785            785             785
#                     1                541            541             541
#        nonCaucasian 0               1334           1334            1334
#                     1               1460           1460            1460
#
#                                     juv_other_count  priors_count  \
# sex    race_bin     two_year_recid
# Female Caucasian    0                           262           262
#                     1                           143           143
#        nonCaucasian 0                           373           373
#                     1                           197           197
# Male   Caucasian    0                           785           785
#                     1                           541           541
#        nonCaucasian 0                          1334          1334
#                     1                          1460          1460
#
#                                     age_cat_25 - 45  age_cat_Greater than 45  \
# sex    race_bin     two_year_recid
# Female Caucasian    0                           262                      262
#                     1                           143                      143
#        nonCaucasian 0                           373                      373
#                     1                           197                      197
# Male   Caucasian    0                           785                      785
#                     1                           541                      541
#        nonCaucasian 0                          1334                     1334
#                     1                          1460                     1460
#
#                                     age_cat_Less than 25  c_charge_degree_F  \
# sex    race_bin     two_year_recid
# Female Caucasian    0                                262                262
#                     1                                143                143
#        nonCaucasian 0                                373                373
#                     1                                197                197
# Male   Caucasian    0                                785                785
#                     1                                541                541
#        nonCaucasian 0                               1334               1334
#                     1                               1460               1460
#
#                                     c_charge_degree_M  ...  \
# sex    race_bin     two_year_recid                     ...
# Female Caucasian    0                             262  ...
#                     1                             143  ...
#        nonCaucasian 0                             373  ...
#                     1                             197  ...
# Male   Caucasian    0                             785  ...
#                     1                             541  ...
#        nonCaucasian 0                            1334  ...
#                     1                            1460  ...
#
#                                     c_charge_desc_Resist Officer w/Violence  \
# sex    race_bin     two_year_recid
# Female Caucasian    0                                                   262
#                     1                                                   143
#        nonCaucasian 0                                                   373
#                     1                                                   197
# Male   Caucasian    0                                                   785
#                     1                                                   541
#        nonCaucasian 0                                                  1334
#                     1                                                  1460
#
#                                     c_charge_desc_Resist/Obstruct W/O Violence  \
# sex    race_bin     two_year_recid
# Female Caucasian    0                                                      262
#                     1                                                      143
#        nonCaucasian 0                                                      373
#                     1                                                      197
# Male   Caucasian    0                                                      785
#                     1                                                      541
#        nonCaucasian 0                                                     1334
#                     1                                                     1460
#
#                                     c_charge_desc_Susp Drivers Lic 1st Offense  \
# sex    race_bin     two_year_recid
# Female Caucasian    0                                                      262
#                     1                                                      143
#        nonCaucasian 0                                                      373
#                     1                                                      197
# Male   Caucasian    0                                                      785
#                     1                                                      541
#        nonCaucasian 0                                                     1334
#                     1                                                     1460
#
#                                     c_charge_desc_Tamper With Witness/Victim/CI  \
# sex    race_bin     two_year_recid
# Female Caucasian    0                                                       262
#                     1                                                       143
#        nonCaucasian 0                                                       373
#                     1                                                       197
# Male   Caucasian    0                                                       785
#                     1                                                       541
#        nonCaucasian 0                                                      1334
#                     1                                                      1460
#
#                                     c_charge_desc_Tampering With Physical Evidence  \
# sex    race_bin     two_year_recid
# Female Caucasian    0                                                          262
#                     1                                                          143
#        nonCaucasian 0                                                          373
#                     1                                                          197
# Male   Caucasian    0                                                          785
#                     1                                                          541
#        nonCaucasian 0                                                         1334
#                     1                                                         1460
#
#                                     c_charge_desc_Uttering a Forged Instrument  \
# sex    race_bin     two_year_recid
# Female Caucasian    0                                                      262
#                     1                                                      143
#        nonCaucasian 0                                                      373
#                     1                                                      197
# Male   Caucasian    0                                                      785
#                     1                                                      541
#        nonCaucasian 0                                                     1334
#                     1                                                     1460
#
#                                     c_charge_desc_Viol Injunct Domestic Violence  \
# sex    race_bin     two_year_recid
# Female Caucasian    0                                                        262
#                     1                                                        143
#        nonCaucasian 0                                                        373
#                     1                                                        197
# Male   Caucasian    0                                                        785
#                     1                                                        541
#        nonCaucasian 0                                                       1334
#                     1                                                       1460
#
#                                     c_charge_desc_arrest case no charge  race  \
# sex    race_bin     two_year_recid
# Female Caucasian    0                                               262   262
#                     1                                               143   143
#        nonCaucasian 0                                               373   373
#                     1                                               197   197
# Male   Caucasian    0                                               785   785
#                     1                                               541   541
#        nonCaucasian 0                                              1334  1334
#                     1                                              1460  1460
#
#                                     sample
# sex    race_bin     two_year_recid
# Female Caucasian    0                  262
#                     1                  143
#        nonCaucasian 0                  373
#                     1                  197
# Male   Caucasian    0                  785
#                     1                  541
#        nonCaucasian 0                 1334
#                     1                 1460
#
# [8 rows x 65 columns]

# %%
save_dir = '/data/MLTdata/compas/dataset_processed/'
mkdir(save_dir)
df_cat.to_csv(save_dir+'bpf_dataset_cat.csv',index=0)

# %% [markdown]
# ### Checking dataset splitting

# %%
from dataloaders.datasets import Compas_pandas

train_df,test_df,cov_tags = Compas_pandas(groups_list = ['race_bin','sex'],
                                            utility = 'two_year_recid',norm_std = True,split=1)
# Out:
#  Split :  1  is loaded...
# ['train'] ['test']
# ------- Compas Dataset processing ----------
# utility :  two_year_recid ; stratification_tags :  ['race_bin', 'sex', 'two_year_recid'] ; standarization :  True ; len(cov_tags) :  63
# ntrain :  4076  ; ntest :  1019
# check: overlap train and test ?  False
# ../dataloaders/datasets.py:162: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd_train[c] = (pd_train[c].values - mean) / std
# ../dataloaders/datasets.py:163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pd_test[c] = (pd_test[c].values - mean) / std

# %%
print('train : ', len(train_df), ' samples')
print(train_df.groupby(['strat'])['utility'].count() / len(train_df))
print()
print('test : ', len(test_df), ' samples')
print(test_df.groupby(['strat'])['utility'].count() / len(test_df))
print()

train_df.head()
# Out:
# train :  4076  samples
# strat
# Caucasian,Female,0,       0.051276
# Caucasian,Female,1,       0.028214
# Caucasian,Male,0,         0.154073
# Caucasian,Male,1,         0.106232
# nonCaucasian,Female,0,    0.073111
# nonCaucasian,Female,1,    0.038763
# nonCaucasian,Male,0,      0.261776
# nonCaucasian,Male,1,      0.286555
# Name: utility, dtype: float64
#
# test :  1019  samples
# strat
# Caucasian,Female,0,       0.052012
# Caucasian,Female,1,       0.027478
# Caucasian,Male,0,         0.154073
# Caucasian,Male,1,         0.105986
# nonCaucasian,Female,0,    0.073602
# nonCaucasian,Female,1,    0.038273
# nonCaucasian,Male,0,      0.262022
# nonCaucasian,Male,1,      0.286555
# Name: utility, dtype: float64
#         age  juv_fel_count  juv_misd_count  juv_other_count  priors_count  \
# 0  2.957248      -0.128684       -0.183274        -0.232776     -0.691628
# 1 -0.046439      -0.128684       -0.183274        -0.232776     -0.691628
# 2 -0.904635      -0.128684       -0.183274         1.888855      0.140105
# 3  0.811758      -0.128684       -0.183274        -0.232776     -0.691628
# 4  0.554299      -0.128684       -0.183274        -0.232776      2.219437
#
#    age_cat_25 - 45  age_cat_Greater than 45  age_cat_Less than 25  \
# 0        -1.172141                 1.953187             -0.521029
# 1         0.852972                -0.511883             -0.521029
# 2        -1.172141                -0.511883              1.918901
# 3         0.852972                -0.511883             -0.521029
# 4         0.852972                -0.511883             -0.521029
#
#    c_charge_degree_F  c_charge_degree_M  ...  \
# 0           0.765587          -0.765587  ...
# 1           0.765587          -0.765587  ...
# 2           0.765587          -0.765587  ...
# 3          -1.305930           1.305930  ...
# 4           0.765587          -0.765587  ...
#
#    c_charge_desc_arrest case no charge              race      race_bin   sex  \
# 0                            -0.426409             Other  nonCaucasian  Male
# 1                            -0.426409  African-American  nonCaucasian  Male
# 2                            -0.426409  African-American  nonCaucasian  Male
# 3                            -0.426409             Other  nonCaucasian  Male
# 4                            -0.426409         Caucasian     Caucasian  Male
#
#    two_year_recid  sample  utility  sample_index                 strat  \
# 0               0       0        0             0  nonCaucasian,Male,0,
# 1               1       1        1             1  nonCaucasian,Male,1,
# 2               1       2        1             2  nonCaucasian,Male,1,
# 3               0       3        0             3  nonCaucasian,Male,0,
# 4               1       4        1             4     Caucasian,Male,1,
#
#    dataset
# 0    train
# 1    train
# 2    train
# 3    train
# 4    train
#
# [5 rows x 72 columns]
